# %%
import json

path_tweets = 'farmers-protest-tweets-2021-2-4.json'
with open(path_tweets) as t:
    tweets = json.load(t)

tweets
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       3 path_tweets = 'farmers-protest-tweets-2021-2-4.json'
#       4 with open(path_tweets) as t:
# ----> 5     tweets = json.load(t)
#       7 tweets
#
# File c:\Users\migue\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
# ...

# %% [markdown]
# Esto ocurre porque el archivo no es un json como tal, ya que un json contiene solo un diccionario enterno, en cambio este archivo tiene muchos diccionarios externos todos al mismo nivel. Por lo que para trabajar con él hay que leer linea a linea, y decodificar el json.

# %%
json_lines = []
with open(path_tweets) as t:
    for i, line in enumerate(t):
        json_lines.append(line)
        if i >= 5:
            break
json_lines
# Out:
# ['{"url": "https://twitter.com/ArjunSinghPanam/status/1364506249291784198", "date": "2021-02-24T09:23:35+00:00", "content": "The world progresses while the Indian police and Govt are still trying to take India back to the horrific past through its tyranny. \\n\\n@narendramodi @DelhiPolice Shame on you. \\n\\n#ModiDontSellFarmers \\n#FarmersProtest \\n#FreeNodeepKaur https://t.co/es3kn0IQAF", "renderedContent": "The world progresses while the Indian police and Govt are still trying to take India back to the horrific past through its tyranny. \\n\\n@narendramodi @DelhiPolice Shame on you. \\n\\n#ModiDontSellFarmers \\n#FarmersProtest \\n#FreeNodeepKaur twitter.com/ravisinghka/st\\u2026", "id": 1364506249291784198, "user": {"username": "ArjunSinghPanam", "displayname": "Arjun Singh Panam", "id": 45091142, "description": "Global Citizen, Actor, Director: Sky is the roof above my head, the world is the road I travel, love is my food & mother earth is my bed. Roy in @CosmosMovie", "rawDesc
# ...

# %%
import pandas as pd

df_tweets = pd.read_json(path_tweets, lines = True, nrows = 5)
df_tweets
# Out:
#                                                  url  \
# 0  https://twitter.com/ArjunSinghPanam/status/136...
# 1  https://twitter.com/PrdeepNain/status/13645062...
# 2  https://twitter.com/parmarmaninder/status/1364...
# 3  https://twitter.com/anmoldhaliwal/status/13645...
# 4  https://twitter.com/KotiaPreet/status/13645061...
#
#                        date  \
# 0 2021-02-24 09:23:35+00:00
# 1 2021-02-24 09:23:32+00:00
# 2 2021-02-24 09:23:22+00:00
# 3 2021-02-24 09:23:16+00:00
# 4 2021-02-24 09:23:10+00:00
#
#                                              content  \
# 0  The world progresses while the Indian police a...
# 1  #FarmersProtest \n#ModiIgnoringFarmersDeaths \...
# 2  ਪੈਟਰੋਲ ਦੀਆਂ ਕੀਮਤਾਂ ਨੂੰ ਮੱਦੇਨਜ਼ਰ ਰੱਖਦੇ ਹੋਏ \nਮੇ...
# 3  @ReallySwara @rohini_sgh watch full video here...
# 4  #KisanEktaMorcha #FarmersProtest #NoFarmersNoF...
#
#                                      renderedContent                   id  \
# ...

# %%
df_tweets.columns
# Out:
# Index(['url', 'date', 'content', 'renderedContent', 'id', 'user', 'outlinks',
#        'tcooutlinks', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'lang', 'source', 'sourceUrl', 'sourceLabel', 'media',
#        'retweetedTweet', 'quotedTweet', 'mentionedUsers'],
#       dtype='object')

# %%
pd.options.display.max_colwidth = None
pd.options.display.max_columns = None
df_tweets.head(1)
# Out:
#                                                               url  \
# 0  https://twitter.com/ArjunSinghPanam/status/1364506249291784198
#
#                        date  \
# 0 2021-02-24 09:23:35+00:00
#
#                                                                                                                                                                                                                                                                  content  \
# 0  The world progresses while the Indian police and Govt are still trying to take India back to the horrific past through its tyranny. \n\n@narendramodi @DelhiPolice Shame on you. \n\n#ModiDontSellFarmers \n#FarmersProtest \n#FreeNodeepKaur https://t.co/es3kn0IQAF
#
# ...
